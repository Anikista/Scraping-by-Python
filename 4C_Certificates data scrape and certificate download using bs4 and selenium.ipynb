# %%
import selenium                                                
import pandas as pd 
import re
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
import time
from selenium.webdriver.common.action_chains import ActionChains
import string
import os, platform
import requests
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager      
driver = webdriver.Chrome(ChromeDriverManager().install())
#driver = webdriver.Chrome(executable_path='/Users/User/Upwork Project/PlanetX/chromedriver')
driver.maximize_window()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [C:\Users\USER\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# C:\Users\USER\AppData\Local\Temp\ipykernel_17160\3088977505.py:19: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
url = 'https://www.4c-services.org/process/list-of-4c-certificates/'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
Dic = {}
gc= pd.DataFrame(data=Dic,index=[0], 
                columns=['Country',
                        'Certificate Holder',
                        'Certificate No.',
                        'Valid From',
                        'Valid To',
                        'CB*',
                        'Scope',
                        'PDF'])
gc

# %%
Dic2 = {}
gc2 = pd.DataFrame(data=Dic2,index=[0], 
                columns=['Country',
                        'Certificate Holder',
                        'Certificate No.',
                        'Valid From',
                        'Valid To',
                        'CB*',
                        'Scope'])
gc2
# Out:
#   Country Certificate Holder Certificate No. Valid From Valid To  CB* Scope
# 0     NaN                NaN             NaN        NaN      NaN  NaN   NaN

# %%
crtfc = soup.find('table', id = 'tablepress-4')
for cntry in crtfc.find_all('tbody'):
    rows = cntry.find_all('tr')
    for row in rows:
        coun = row.find_all('td')[0].text
        ch = row.find_all('td')[1].text
        cno = row.find_all('td')[2].text
        vf = row.find_all('td')[3].text
        vt = row.find_all('td')[4].text
        cb = row.find_all('td')[5].text
        sc = row.find_all('td')[6].text
        Dic = {'Country':coun,
                        'Certificate Holder':ch,
                        'Certificate No.':cno,
                        'Valid From':vf,
                        'Valid To':vt,
                        'CB*':cb,
                        'Scope':sc}
        gc = gc.append(Dic, ignore_index=True)
        print(gc)

# %%
gc

# %%
gc.to_excel('4C0.xlsx')

# %%
url = 'https://www.4c-services.org/process/list-of-4c-certificates/'
driver.get(url)

# %%
for j in range(22):
    for i in range(10):
        clk = driver.find_elements(By.CSS_SELECTOR, '#tablepress-4 > tbody > tr > td.column-8 > a')
        clk = clk[i]
        driver.execute_script("arguments[0].click();", clk)

    clk2 = driver.find_element(By.CSS_SELECTOR, '#tablepress-4_paginate > a.paginate_button.next')
    driver.execute_script("arguments[0].click();", clk2)

# %%
crtfc = soup.find('table', id = 'tablepress-5')
for cntry in crtfc.find_all('tbody'):
    rows = cntry.find_all('tr')
    for row in rows:
        coun = row.find_all('td')[0].text
        ch = row.find_all('td')[1].text
        cno = row.find_all('td')[2].text
        vf = row.find_all('td')[3].text
        vt = row.find_all('td')[4].text
        cb = row.find_all('td')[5].text
        sc = row.find_all('td')[6].text
        Dic2 = {'Country':coun,
                        'Certificate Holder':ch,
                        'Certificate No.':cno,
                        'Valid From':vf,
                        'Valid To':vt,
                        'CB*':cb,
                        'Scope':sc}
        gc2 = gc2.append(Dic2, ignore_index=True)
        print(gc2)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_17160\2176025088.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc2 = gc2.append(Dic2, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_17160\2176025088.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc2 = gc2.append(Dic2, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_17160\2176025088.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc2 = gc2.append(Dic2, ignore_index=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_17160\2176025088.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gc2 = gc2.append(Dic2, ignore_index=True)
# ...

# %%
gc2
# Out:
#     Country                                 Certificate Holder  \
# 0       NaN                                                NaN
# 1    Brazil  Bryser Café Exportação e Importação Ltda.Bryse...
# 2    Brazil  Cafebras - Comércio de Cafés do Brasil S.A.Caf...
# 3    Brazil  Cooperativa dos Cafeicultores da Zona de Três ...
# 4    Brazil  Cooabriel - Cooperativa Agrária dos Cafeiculto...
# ..      ...                                                ...
# 73  Vietnam  Olam Vietnam LimitedOlam Vietnam Limited - Dak...
# 74  Vietnam   Phuc Minh Trade Ltd. Co.Phuc Minh Trade Ltd. Co.
# 75  Vietnam              Simexco DakLak Ltd.Simexco DakLak III
# 76  Vietnam  Tran Minh Hung Lam Ha Limited CompanyTran Minh...
# 77  Vietnam   Tuan Phat Coffee Co.,LtdTuan Phat Coffee Co.,Ltd
#
#                 Certificate No.  Valid From    Valid To    CB*  \
# 0                           NaN         NaN         NaN    NaN
# 1   L-20183-06-1-1121*(expired)  2020-07-23  2021-11-07    SCS
# ...

# %%
gc2.to_excel('4C2.xlsx')

# %%
for j in range(22):
    for i in range(10):
        clk = driver.find_elements(By.CSS_SELECTOR, '#tablepress-5 > tbody > tr > td.column-8 > a')
        clk = clk[i]
        driver.execute_script("arguments[0].click();", clk)

    clk2 = driver.find_element(By.CSS_SELECTOR, '#tablepress-5_paginate > a.paginate_button.next')
    driver.execute_script("arguments[0].click();", clk2)
